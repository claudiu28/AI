# %%
import torch
from transformers import GPT2Tokenizer, GPT2LMHeadModel, AutoTokenizer, AutoModelForCausalLM

def generate_poetry(model, tokenizer, prompt, max_length=500, temperature=0.8, top_p=0.95, top_k=50,
                    num_return_sequences=1):
    inputs = tokenizer.encode(prompt, return_tensors='pt')
    attention_mask = torch.ones_like(inputs)

    if tokenizer.pad_token is None: tokenizer.pad_token = tokenizer.eos_token

    with torch.no_grad():
        outputs = model.generate(
            inputs,
            attention_mask=attention_mask,
            max_length=max_length,
            temperature=temperature,
            top_p=top_p,
            top_k=top_k,
            num_return_sequences=num_return_sequences,
            pad_token_id=tokenizer.pad_token_id,
            eos_token_id=tokenizer.eos_token_id,
            do_sample=True,
            no_repeat_ngram_size=4
        )

    return [tokenizer.decode(output, skip_special_tokens=True, clean_up_tokenization_spaces=True) for output in outputs]


# A. GPT - 2 => Normal 
def test_gpt2_general():
    model_name = "gpt2"
    tokenizer = GPT2Tokenizer.from_pretrained(model_name)
    model = GPT2LMHeadModel.from_pretrained(model_name)
    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token

    prompts = [
        ("Prompt RO", "Continuă o poezie romantică, filosofică, în stilul lui Mihai Eminescu, pornind de la versul: A fost o dată ca-n povești"),
        ("Prompt EN", "Continue a romantic and philosophical poem in the style of Mihai Eminescu, starting with the line: It once was like in fairy tales,"),
    ]

    params = {"temperature": 0.8, "top_p": 0.95, "top_k": 200}

    for label, prompt in prompts:
        print(f"\nPrompt: {prompt}")
        results = generate_poetry(model, tokenizer, prompt, **params)
        for i, result in enumerate(results):
            print(f"{result}\n")


# B. Model Special
def test_gpt2_poetry_model():
    model_name = "matthh/gpt2-poetry-model"
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForCausalLM.from_pretrained(model_name)
    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token

    prompts = [
        ("Prompt RO", "Continuă o poezie romantică, filosofică, în stilul lui Mihai Eminescu, pornind de la versul: A fost o dată ca-n povești"),
        ("Prompt EN", "Continue a romantic and philosophical poem in the style of Mihai Eminescu, starting with the line: It once was like in fairy tales,"),
    ]

    params = {"temperature": 0.8, "top_p": 0.95, "top_k": 200}

    for label, prompt in prompts:
        print(f"Prompt: {prompt}")
        results = generate_poetry(model, tokenizer, prompt, **params)
        for i, result in enumerate(results):
            print(f"\n{result}")


test_gpt2_general()
test_gpt2_poetry_model()
# Out:
# Prompt: Continuă o poezie romantică, filosofică, în stilul lui Mihai Eminescu, pornind de la versul: A fost o dată ca-n povești
# Continuă o poezie romantică, filosofică, în stilul lui Mihai Eminescu, pornind de la versul: A fost o dată ca-n povești.
#
# — E dicieră ți, uda lein zemniă, pla u ăi, siă alină luce, voă sis.
#
# I am sorry for the delay, it has taken so long.
#
# The woman who told me about this was the only one who had experienced her ex-husband's brutal attack, which she said she had witnessed in his office. She said she had never seen such an attack like it in her life. And what was she saying?
#
# "The woman who witnessed the assault was the only member of our family in my life. The man who assaulted me, I believe, was married to my brother, but he kept to himself. I was asked to help him as a friend. I told him to leave the building in order to get to safety. He was immediately shot. He told me to get out of my house and leave the place, as I was on my way. The woman who watched the attack was the only woman who knew that he was a murderer."
#
# — Želemu mieă, konneči raznaă, povină mejă gegii, jovaniam lui na Želihai.
#
# She didn't have a clue that this was how it happened and how she was affected. But all she had to do was that she found a picture on the wall of the house.
#
# "Another neighbor was also shocked at her. He said that he saw a man on the street saying that he was from a village. He had never seen this man before, so he was shocked that he had seen such a thing."
#
# The man is a man who lived in the street at the time, but he was known as the person who attacked her.
#
# Later, he told me that he heard his brother's screams and felt that the family was being forced to call him by some other name. The man had no idea that the incident was being referred to by the person who murdered her.
# .
#
# They
#
#
# Prompt: Continue a romantic and philosophical poem in the style of Mihai Eminescu, starting with the line: It once was like in fairy tales,
# Continue a romantic and philosophical poem in the style of Mihai Eminescu, starting with the line: It once was like in fairy tales, there were no good fairy tales, and there were no bad fairy tales.
#
# People say that it's difficult to write your own writing in Spanish. I say it's hard for me to write in Spanish.
#
# And you can't just say your own words. You have to do it with your whole brain.
#
# You've got to write the words with a very precise brain and a very deep, deep understanding of the language.
#
# But when you write in a Spanish poem, you have to write in a foreign language, and you can't write in a Japanese poem. So you have to work at it, for two or three years. You have two or three months to do it. You have a lot of freedom.
#
# So, I want to write in one of the beautiful, beautiful languages of the world.
#
# I want to write poems in a beautiful and beautiful language.
# ,
#
# .
#
# .
#
# Prompt: Continuă o poezie romantică, filosofică, în stilul lui Mihai Eminescu, pornind de la versul: A fost o dată ca-n povești
#
# Continuă o poezie romantică, filosofică, în stilul lui Mihai Eminescu, pornind de la versul: A fost o dată ca-n povești, ullă, de lupli, înnis.
#
# Dovors, dovors, gars, dovor muy leblia povos, dovores, dovos, gars muy lebia povolă, dovovors, leblia ullĂra, de lubăr yi, ullo, căra, ad īna yi, ad ūs, ad ōd, ad izim, ad ile, ad uă, ad șlă, en la cœn, ad ia, ad iae, ad iană, si, cu, en, en, īn, cĂ, cu, de, en, on, en, nu, se, en, se, ne, en, povos.
#
# Eőu wă, eőu, dó, fejă, vi, la, la, el, de, lu, pu, le, œ, le, si, on, ia, lu-s, si, ne, si, la, on, on, ană, luă-s, en, al, on, ar, anĂ, la, en, eœ, en, anē, cą, luœ, cu, ad, ullos, ad, eżu, eŒ, le, la, lo, li, de, on, eśo, la, ad, lu�n, re, de, la, si, en, pr, ne, pr, en, mi, on, preă, ne, a, on, a, fe, ma, on, ă, li-o, en, li-l, on, as, on, lu(ă).
#
# Ečost, inčost, mam, są, mă,
# Prompt: Continue a romantic and philosophical poem in the style of Mihai Eminescu, starting with the line: It once was like in fairy tales,
#
# Continue a romantic and philosophical poem in the style of Mihai Eminescu, starting with the line: It once was like in fairy tales, it was like in old gods.
#
# More than anything, it was the whole world, as it was the only world in which God could be imagined. All of us were made, all of us were conceived, all of our existence is the result of God, all of that is our own.
#
# This statement by the author of My Life (Oxford, 1988) in the December 1990 issue of the Christian Science Monitor is not a surprise, as the same year (1990) she wrote a book about her life.
#
# In her commentary on the book, she writes, "My life is, by far, the most beautiful I have ever seen, though with the exception of the first few days. On this day I saw the best of God, which is not in vain. I was surrounded by all sorts of people, but only by my own kind, and one thing was clear: In the Christian religion I had never seen an image of God. And while it was true that God had created the world, he never saw a human being. We were made of a single human being, made of a variety of people, and God never saw the man. God had made all things the way they are. Then he saw a man, and a woman, and a child, and a king. And God never saw anything like what we do today, and that is in the body. So I could see God alone and I could see Him as being on the line of the cosmos, but not as being the whole of the universe. In this way God was no different from men, and there was nothing strange about the fact that he had made man. And God himself is the man, and he is the God of all men. It is not necessary to think of men as a man or a God, that is, to think of God as the divine and the divine being. The creation, he explained, is nothing but an image of the divine being, which is the image of the truth and of God, or God being man and being God."
#
# The comments on this quote by the author are often cited by supporters of modern Christianity as proof that the Bible does not contain any kind of God.
#
# "For in the first century, however, all the revelations were brought to light. The
